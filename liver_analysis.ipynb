# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('indian_liver_patient.csv')

# %%
data.shape
# Out:
# (583, 11)

# %%
print(data.head(5))
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
data.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# ...

# %%
data.max()
# Out:
# Age                             90
# Gender                        Male
# Total_Bilirubin                 75
# Direct_Bilirubin              19.7
# Alkaline_Phosphotase          2110
# Alamine_Aminotransferase      2000
# Aspartate_Aminotransferase    4929
# Total_Protiens                 9.6
# Albumin                        5.5
# Albumin_and_Globulin_Ratio     2.8
# Dataset                          2
# dtype: object

# %%
data.mean()
# Out:
# Age                            44.746141
# Total_Bilirubin                 3.298799
# Direct_Bilirubin                1.486106
# Alkaline_Phosphotase          290.576329
# Alamine_Aminotransferase       80.713551
# Aspartate_Aminotransferase    109.910806
# Total_Protiens                  6.483190
# Albumin                         3.141852
# Albumin_and_Globulin_Ratio      0.947064
# Dataset                         1.286449
# dtype: float64

# %%
data.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %%
new=data['Albumin_and_Globulin_Ratio'].fillna(data['Albumin_and_Globulin_Ratio'].mean())

# %%
data['Albumin_and_Globulin_Ratio']=new

# %%
data.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %%
data['Age'].corr(data['Total_Bilirubin'])
# Out:
# 0.011762651414898804

# %%
data['Albumin'].corr(data['Albumin_and_Globulin_Ratio'])
# Out:
# 0.68632182229883643

# %%
data['Alkaline_Phosphotase'].corr(data['Alamine_Aminotransferase'])
# Out:
# 0.12567995086767314

# %%
data['Aspartate_Aminotransferase'].corr(data['Alamine_Aminotransferase'])
# Out:
# 0.79196568485361307

# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
samp = data.head(10)
sns.barplot(y='Age',x='Gender',data=samp)
plt.show()

# %%
import numpy as np 
series = pd.Series(np.random.rand(4), index=['Age', 'Gender', 'Total_Protiens', 'Total_Bilirubin'], name='series')

# %%
series.plot.pie(figsize=(5, 5))

# %%
data.plot(kind='scatter', x='Alkaline_Phosphotase', y='Total_Bilirubin')

# %%
p=data.groupby("Age")
p.head(2)
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# 5     46    Male              1.8               0.7                   208
# 6     26  Female              0.9               0.2                   154
# 7     29  Female              0.9               0.3                   202
# 8     17    Male              0.9               0.3                   202
# 9     55    Male              0.7               0.2                   290
# 10    57    Male              0.6               0.1                   210
# 11    72    Male              2.7               1.3                   260
# ...

# %%
data.Age.hist()
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Total_Protiens')
plt.savefig('hist_age')

# %%
data['Aspartate_Aminotransferase'].median()
# Out:
# 42.0

# %%
data['Direct_Bilirubin'].std()
# Out:
# 2.8084976176589636

# %%
x= data.iloc[:,2:10]
x.head(5)
# Out:
#    Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0              0.7               0.1                   187
# 1             10.9               5.5                   699
# 2              7.3               4.1                   490
# 3              1.0               0.4                   182
# 4              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio
# 0      3.3                        0.90
# 1      3.2                        0.74
# 2      3.3                        0.89
# ...

# %%
y=data.iloc[:,-1]
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Dataset, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score,confusion_matrix
from sklearn.metrics import accuracy_score


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)


clf_rf = RandomForestClassifier(random_state=43)      
clr_rf = clf_rf.fit(x_train,y_train)

ac = accuracy_score(y_test,clf_rf.predict(x_test))
print('Accuracy is: ',ac)
# Out:
# Accuracy is:  0.725714285714

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
select_feature = SelectKBest(chi2, k=5).fit(x_train, y_train)

# %%
print('Score list:', select_feature.scores_)
print('Feature list:', x_train.columns)
# Out:
# Score list: [  2.33275496e+02   1.28323987e+02   2.20594047e+03   4.02177457e+03
#    6.74410190e+03   2.31020869e-01   3.06828322e+00   1.30490268e+00]
# Feature list: Index(['Total_Bilirubin', 'Direct_Bilirubin', 'Alkaline_Phosphotase',
#        'Alamine_Aminotransferase', 'Aspartate_Aminotransferase',
#        'Total_Protiens', 'Albumin', 'Albumin_and_Globulin_Ratio'],
#       dtype='object')

# %%
x_train_2 = select_feature.transform(x_train)
x_test_2 = select_feature.transform(x_test)

clf_rf_2 = RandomForestClassifier()      
clr_rf_2 = clf_rf_2.fit(x_train_2,y_train)
ac_2 = accuracy_score(y_test,clf_rf_2.predict(x_test_2))
print('Accuracy is: ',ac_2)
# Out:
# Accuracy is:  0.725714285714

# %%
from sklearn.feature_selection import RFE
clf_rf_3 = RandomForestClassifier()      
rfe = RFE(estimator=clf_rf_3, n_features_to_select=5, step=1)
rfe = rfe.fit(x_train, y_train)

# %%
print('Chosen best 5 feature by rfe:',x_train.columns[rfe.support_])
# Out:
# Chosen best 5 feature by rfe: Index(['Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens',
#        'Albumin_and_Globulin_Ratio'],
#       dtype='object')

# %%
from sklearn.feature_selection import RFECV


clf_rf_4 = RandomForestClassifier() 
rfecv = RFECV(estimator=clf_rf_4, step=1, cv=5,scoring='accuracy')   #5-fold cross-validation
rfecv = rfecv.fit(x_train, y_train)

print('Optimal number of features :', rfecv.n_features_)
print('Best features :', x_train.columns[rfecv.support_])
# Out:
# Optimal number of features : 5
# Best features : Index(['Direct_Bilirubin', 'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Albumin'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score of number of selected features")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=25)

x_train_N = (x_train-x_train.mean())/(x_train.max()-x_train.min())
x_test_N = (x_test-x_test.mean())/(x_test.max()-x_test.min())

from sklearn.decomposition import PCA
pca = PCA()
pca.fit(x_train_N)

plt.figure(1, figsize=(14, 13))
plt.clf()
plt.axes([.2, .2, .7, .7])
plt.plot(pca.explained_variance_ratio_, linewidth=2)

plt.xlabel('n_components')
plt.ylabel('explained_variance_ratio_')
# Out:
# Text(0,0.5,'explained_variance_ratio_')

# %%
from sklearn.metrics import fbeta_score
predictions = (clr_rf.fit(x_train,y_train)).predict(x_test)
print ("Accuracy score on testing data: {:.4f}".format(accuracy_score(y_test, predictions)))
print ("F-score on testing data: {:.4f}".format(fbeta_score(y_test, predictions, beta = 2)))
# Out:
# Accuracy score on testing data: 0.7257
# F-score on testing data: 0.8509

# %%
clf_rf.fit(x, y)
prediction = clf_rf.predict(x_test)


from sklearn.metrics import precision_score, \
    recall_score, confusion_matrix, classification_report, \
    accuracy_score, f1_score

print ('Accuracy:', accuracy_score(y_test, prediction))
print ('F1 score:', f1_score(y_test, prediction))
print ('Recall:', recall_score(y_test, prediction))
print ('Precision:', precision_score(y_test, prediction))
print ('\n clasification report:\n', classification_report(y_test,prediction))
# Out:
# Accuracy: 0.982857142857
# F1 score: 0.988593155894
# Recall: 1.0
# Precision: 0.977443609023
#
#  clasification report:
#               precision    recall  f1-score   support
#
#           1       0.98      1.00      0.99       130
#           2       1.00      0.93      0.97        45
#
# avg / total       0.98      0.98      0.98       175
